# %%
import socks
import socket
import requests
from bs4 import BeautifulSoup

# %%
from urllib.request import urlopen
socks.set_default_proxy(socks.SOCKS5, "localhost",9150)
socket.socket = socks.socksocket

# %%
def getaddrinfo(*args):
    return[(socket.AF_INET, socket.SOCK_STREAM, 6, '', (args[0], args[1]))]

socket.getaddrinfo = getaddrinfo

# %%
res = requests.get("http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/")

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/xmlrpc.php" rel="pingback"/>
#   <title>
#    Black Market – Buy Guns,Buy Cocaine,Buy Counterfeit money,
#   </title>
#   <meta content="max-image-preview:large" name="robots">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch">
#     <link href="//s.w.org" rel="dns-prefetch">
#      <link href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/feed/" rel="alternate" title="Black Market » Feed" type="application/rss+xml"/>
#      <link href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/comments/feed/" rel="alternate" title="Black Market » Comments Feed" type="application/rss+xml"/>
#      <script type="text/javascript">
# ...

# %%
soup.title
# Out:
# <title>Black Market – Buy Guns,Buy Cocaine,Buy Counterfeit money,</title>

# %%
links = [link.get('href') for link in soup.find_all('a')]
links = list(filter(None, links))

# %%
onion = []

for l in links:
    if "onion" in l:
        onion.append(l)

# %%
onion
# Out:
# ['http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/cart/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/checkout/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/shop/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/product-category/guns-for-sale/',
#  'http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/product-category/money-transfers/',
# ...

# %%
links = soup.find_all("body")
print(links)
print("\n")
# Out:
# [<body class="home page-template page-template-templates page-template-fullwidth page-template-templatesfullwidth-php page page-id-5 wp-custom-logo theme-storeone woocommerce-no-js wcfm-theme-storeone">
# ...

# %%
links = soup.find_all("a")
print(links)
# Out:
# [<a class="skip-link screen-reader-text" href="#content">Skip to content</a>, <a href="#"><i class="fa fa-facebook"></i></a>, <a class="top-bl-login" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/"> <i class="fa fa-sign-in"></i> Login </a>, <a class="top-bl-register" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/"> <i class="fa fa-user-plus"></i> Register </a>, <a class="top-bl-cart" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/cart/"> <i class="fa fa-shopping-basket"></i> Cart </a>, <a class="top-bl-checkout" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/checkout/"> <i class="fa fa-check-circle-o"></i> Checkout </a>, <a aria-current="page" class="custom-logo-link" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/" rel="home"><img alt="Black Market" class="custom-logo" height="132" sizes="(max-width: 392px) 100vw, 39
# ...

# %%
for link in links:
    if "Drugs for Sale" in link.text:
        print(link.prettify())
        print(link.attrs['href'])
# Out:
# <a href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/product-category/drugs-for-sale/">
#  Drugs for Sale
# </a>
# http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/product-category/drugs-for-sale/

# %%
tag = soup.find_all('h2')[0]
print(tag)
print(tag.string)
# Out:
# <h2 class="bgs-slider-heading animation animated-item-1"> Cloned Cards </h2>
#  Cloned Cards

# %%
tag.string.replace_with("This is another string")
print(tag)
# Out:
# <h2 class="bgs-slider-heading animation animated-item-1">This is another string</h2>

# %%
tags = soup.find_all("p")
print(tags)
# Out:
# [<p class="site-title"><a href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/" rel="home">Black Market</a></p>, <p class="site-description">Buy Guns,Buy Cocaine,Buy Counterfeit money,</p>, <p class="section-description"> </p>, <p class="section-description"> </p>, <p>Euro banknotes | USD banknotes | fake Australia dollars| fake British Pounds| Canadian dollars,</p>, <p>Visit our <a href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/blog/"><strong>Blog</strong></a> for more Info</p>, <p></p>, <p><strong>Wickr ID :blackmart </strong></p>, <p><strong>Email: alexweeds00@gmail.com</strong></p>, <p>© 2023 Black Market | Theme by <a href="https://themefarmer.com" rel="designer">Theme Farmer</a></p>]

# %%
prices = soup.find_all(text="$")
parent = prices[9].parent
print(parent)
# Out:
# <span class="woocommerce-Price-currencySymbol">$</span>

# %%
tag = soup.find_all('h2')[5]
print(tag)
print(tag.string)
# Out:
# <h2 class="woocommerce-loop-product__title">Taurus G2C Black 9mm Pistol – Blue/Black, 3.2″ Barrel, 12+1 Rounds, Polymer Grips, 3-Dot Sights</h2>
# Taurus G2C Black 9mm Pistol – Blue/Black, 3.2″ Barrel, 12+1 Rounds, Polymer Grips, 3-Dot Sights

# %%
tag = soup.find_all('div')[15]
print(tag)
print(tag.string)
# Out:
# <div class="container">
# <div class="bgs-cart-container pull-right" id="tf-bgs-cart-container">
# <div class="mini-cart-container pull-right">
# <div class="bgs-cart-nav">
# <div class="mini-cart-icon">
# <div class="mini-item-count">0</div>
# <i class="fa fa-shopping-cart"></i>
# </div>
# <div class="mini-cart-details">
# <div class="mini-cart-title">TOTAL</div>
# <div class="mini-cart-total"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>0.00</span></div>
# </div>
# </div>
# <div class="bgs-mini-cart">
# <div class="widget woocommerce widget_shopping_cart"><div class="widget_shopping_cart_content"></div></div> </div>
# </div>
# </div>
# <div class="bgs-menu-container pull-left">
# <nav class="navbar navbar-default bgs-menu">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#TF-Navbar" data-toggle="collapse" type="button">
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# ...

# %%
tag = soup.find_all('div')
parent = tag[2].parent
print(parent)
print(parent.string)
# Out:
# <div class="header-topbar">
# <div class="container">
# <div class="pull-left">
# <ul class="bgs-social">
# <li><a href="#"><i class="fa fa-facebook"></i></a></li>
# </ul>
# </div>
# <div class="pull-right">
# <ul class="account-links"><li><a class="top-bl-login" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/"> <i class="fa fa-sign-in"></i> Login </a></li><li><a class="top-bl-register" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/my-account/"> <i class="fa fa-user-plus"></i> Register </a></li><li><a class="top-bl-cart" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/cart/"> <i class="fa fa-shopping-basket"></i> Cart </a></li><li><a class="top-bl-checkout" href="http://muwgjdckwwmhyi7lj73dspumrxmzuzjvujmtmyrhhbjrgswcakobtfad.onion/checkout/"> <i class="fa fa-check-circle-o"></i> Checkout </a></li></ul> </div>
# </div>
# </div>
# None

# %%
div_price = []
price = soup.find_all('span',{'class':'price'})
print(price)
# Out:
# [<span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>325.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>400.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>245.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>990.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>1,000.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>800.00</bdi></span></span>, <span class="price"><span class="woocommerce-Price-amount amount"><bdi>
# ...

# %%
prices = soup.find_all('bdi')

for price in prices:
    if "$" in price.text:
        print(price.prettify())
# Out:
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  325.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  400.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  245.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  990.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  1,000.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  800.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  99.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  350.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  3,500.00
# </bdi>
# <bdi>
#  <span class="woocommerce-Price-currencySymbol">
#   $
#  </span>
#  800.00
# </bdi>
# <bdi>
# ...
